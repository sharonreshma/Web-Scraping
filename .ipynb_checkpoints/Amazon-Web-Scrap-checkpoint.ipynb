# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install bs4

# %%
# !pip install requests

# %%
# !pip install pandas

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
URL = "https://www.amazon.com/s?k=laptop&crid=2HSSNQHCRKZ7K&sprefix=laptop%2Caps%2C478&ref=nb_sb_noss_1"

# %%
HEADERS = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.5',
    'Accept-Encoding': 'gzip, deflate, br',
    'Connection': 'keep-alive',
    'Upgrade-Insecure-Requests': '1',
    'Sec-Fetch-Dest': 'document',
    'Sec-Fetch-Mode': 'navigate',
    'Sec-Fetch-Site': 'none',
    'Sec-Fetch-User': '?1'
}

# %%
webpage = requests.get(URL, headers=HEADERS)

# %%
webpage
# Out:
# <Response [200]>

# %%
webpage.content
# Out:
# b'<!doctype html><html lang="en-us" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->\n<head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>\n<!-- sp:end-feature:head-start -->\n<!-- sp:feature:csm:head-open-part1 -->\n\n<script type=\'text/javascript\'>var ue_t0=ue_t0||+new Date();</script>\n<!-- sp:end-feature:csm:head-open-part1 -->\n<!-- sp:feature:cs-optimization -->\n<meta http-equiv=\'x-dns-prefetch-control\' content=\'on\'>\n<link rel="dns-prefetch" href="https://images-na.ssl-images-amazon.com">\n<link rel="dns-prefetch" href="https://m.media-amazon.com">\n<link rel="dns-prefetch" href="https://completion.amazon.com">\n<!-- sp:end-feature:cs-optimization -->\n<!-- sp:feature:csm:head-open-part2 -->\n<script type=\'text/javascript\'>\nwindow.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;\nif (window.ue_ihb === 1) {\n\nvar ue_csm = window,\n    ue_hob = +new Date();\n(function(d){var e=d.ue=d.ue||{},f=Date.now||function
# ...

# %%
type(webpage.content)
# Out:
# bytes

# %%
soup = BeautifulSoup(webpage.content, "html.parser")

# %%
linkss = soup.find_all("a", attrs={'class':'<a class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal" href="/jumper-Processor-Display-Speakers-Subscription/dp/B0D69YTLRF/ref=sr_1_3?crid=2HSSNQHCRKZ7K&amp;dib=eyJ2IjoiMSJ9.W21rJ6xKjYGQqfrTyA2aqmOTyw3aIMoLRCBGpi3kB408UWC-H8P2wvj5gXpzR9t2BElfW__4CxQYCTNcRycdiHDkbebkSIWRk95D7xaDttTTDw5EpEHb883AcOhUZLoHJXfrqb0SKaA-pEdjNwID5ib0-8ZHJAMlNREV3eLUe9QddG3pfvhZApBmosEN4sztH48FhaqsFHCU5bZ9r0MdduVJ-P7PbfPZl_8r7RV-Z10.Le2IvT7iV2BqYU5zLEoE5IAzkBAp6Ru4kjkY1O4zh-w&amp;dib_tag=se&amp;keywords=laptop&amp;qid=1719757281&amp;sprefix=laptop%2Caps%2C478&amp;sr=8-3"><span class="a-size-medium a-color-base a-text-normal">jumper Laptop, 4GB DDR4 RAM 128GB SSD, 5205U Processor, 15.6" HD Display, Windows 11, 38Wh Battery, Dual Stereo Speakers, Type-C, USB3.0, Numeric Keypad, Office 365 1-Year Subscription.</span> </a>'})

# %%
linkss
# Out:
# []

# %%
links[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 links[0]
#
# IndexError: list index out of range

# %%
links = soup.find_all("a", class_="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal")

# %%
links
# Out:
# [<a class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal" href="/sspa/click?ie=UTF8&amp;spc=MTozODc0NTU5NTkxMTU4ODI2OjE3MTk3NTczMDQ6c3BfYXRmOjMwMDE2MzY2OTMzODQwMjo6MDo6&amp;url=%2FACEMAGIC-Traditional-Performance-Core-12th-Battery-Silver%2Fdp%2FB0CYSQK8XF%2Fref%3Dsr_1_1_sspa%3Fcrid%3D2HSSNQHCRKZ7K%26dib%3DeyJ2IjoiMSJ9.W21rJ6xKjYGQqfrTyA2aqmOTyw3aIMoLRCBGpi3kB408UWC-H8P2wvj5gXpzR9t2BElfW__4CxQYCTNcRycdiHDkbebkSIWRk95D7xaDttTTDw5EpEHb883AcOhUZLoHJXfrqb0SKaA-pEdjNwID5ib0-8ZHJAMlNREV3eLUe9QddG3pfvhZApBmosEN4sztH48FhaqsFHCU5bZ9r0MdduVJ-P7PbfPZl_8r7RV-Z10.4hMukewCc9fa3cIwcJYW6ES2rN1te2xNxyXGPcFaJmQ%26dib_tag%3Dse%26keywords%3Dlaptop%26qid%3D1719757304%26sprefix%3Dlaptop%252Caps%252C478%26sr%3D8-1-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1"><span class="a-size-medium a-color-base a-text-normal">ACEMAGIC 17.3inch Traditional Laptop Computer,with High Performance Quad Core-12th Alder Lake N97 Laptop,Spacious Storage with 16GB RAM 512GB ROM,Long Lastin
# ...

# %%
link=links[0].get('href')

# %%
product_list="https://amazon.in"+link

# %%
product_list
# Out:
# 'https://amazon.in/sspa/click?ie=UTF8&spc=MTozODc0NTU5NTkxMTU4ODI2OjE3MTk3NTczMDQ6c3BfYXRmOjMwMDE2MzY2OTMzODQwMjo6MDo6&url=%2FACEMAGIC-Traditional-Performance-Core-12th-Battery-Silver%2Fdp%2FB0CYSQK8XF%2Fref%3Dsr_1_1_sspa%3Fcrid%3D2HSSNQHCRKZ7K%26dib%3DeyJ2IjoiMSJ9.W21rJ6xKjYGQqfrTyA2aqmOTyw3aIMoLRCBGpi3kB408UWC-H8P2wvj5gXpzR9t2BElfW__4CxQYCTNcRycdiHDkbebkSIWRk95D7xaDttTTDw5EpEHb883AcOhUZLoHJXfrqb0SKaA-pEdjNwID5ib0-8ZHJAMlNREV3eLUe9QddG3pfvhZApBmosEN4sztH48FhaqsFHCU5bZ9r0MdduVJ-P7PbfPZl_8r7RV-Z10.4hMukewCc9fa3cIwcJYW6ES2rN1te2xNxyXGPcFaJmQ%26dib_tag%3Dse%26keywords%3Dlaptop%26qid%3D1719757304%26sprefix%3Dlaptop%252Caps%252C478%26sr%3D8-1-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1'

# %%
new_webpage=requests.get(product_list,headers=HEADERS)

# %%
webpage
# Out:
# <Response [200]>

# %%
new_soup=BeautifulSoup(new_webpage.content,"html.parser")

# %%
new_soup
# Out:
# <html>
# <head>
# <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
# <title>Page Not Found</title>
# <style type="text/css">
#             a:link { font-family: verdana,arial,helvetica,sans-serif; color: #004B91; }
#             a:visited { font-family: verdana,arial,helvetica,sans-serif; color: #996633; }
#             a:active { font-family: verdana,arial,helvetica,sans-serif; color: #FF9933; }
#         </style>
# </head>
# <body bgcolor="#FFFFFF" style="font-family: verdana,arial,helvetica,sans-serif;" text="#000000">
# <!--
#             To discuss automated access to Amazon data please contact api-services-support@amazon.com.
#
# For information about migrating to our APIs refer to our Marketplace APIs at https://developer.amazonservices.com/ref=rm_5_sv, or our Product Advertising API at https://affiliate-program.amazon.com/gp/advertising/api/detail/main.html/ref=rm_5_ac for advertising use cases.
#         -->
# <center>
# <a href="/ref=cs_404_logo">
# ...

# %%
new_soup.find("span", attrs={"id":'productTitle'}).text.strip()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 new_soup.find("span", attrs={"id":'productTitle'}).text.strip()
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
links = soup.find_all("a", attrs={'class':'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'})

# %%
links
# Out:
# [<a class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal" href="/sspa/click?ie=UTF8&amp;spc=MTozODc0NTU5NTkxMTU4ODI2OjE3MTk3NTczMDQ6c3BfYXRmOjMwMDE2MzY2OTMzODQwMjo6MDo6&amp;url=%2FACEMAGIC-Traditional-Performance-Core-12th-Battery-Silver%2Fdp%2FB0CYSQK8XF%2Fref%3Dsr_1_1_sspa%3Fcrid%3D2HSSNQHCRKZ7K%26dib%3DeyJ2IjoiMSJ9.W21rJ6xKjYGQqfrTyA2aqmOTyw3aIMoLRCBGpi3kB408UWC-H8P2wvj5gXpzR9t2BElfW__4CxQYCTNcRycdiHDkbebkSIWRk95D7xaDttTTDw5EpEHb883AcOhUZLoHJXfrqb0SKaA-pEdjNwID5ib0-8ZHJAMlNREV3eLUe9QddG3pfvhZApBmosEN4sztH48FhaqsFHCU5bZ9r0MdduVJ-P7PbfPZl_8r7RV-Z10.4hMukewCc9fa3cIwcJYW6ES2rN1te2xNxyXGPcFaJmQ%26dib_tag%3Dse%26keywords%3Dlaptop%26qid%3D1719757304%26sprefix%3Dlaptop%252Caps%252C478%26sr%3D8-1-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1"><span class="a-size-medium a-color-base a-text-normal">ACEMAGIC 17.3inch Traditional Laptop Computer,with High Performance Quad Core-12th Alder Lake N97 Laptop,Spacious Storage with 16GB RAM 512GB ROM,Long Lastin
# ...

# %%
URL = "https://www.amazon.com/s?k=playstation+5&crid=3BV45YDFQQE2G&sprefix=playstation+4%2Caps%2C269&ref=nb_sb_noss_2"

# %%
webpage = requests.get(URL, headers=HEADERS)

# %%
type(webpage.content)
# Out:
# bytes

# %%
soup = BeautifulSoup(webpage.content, "html.parser")

# %%
links = soup.find_all("a", attrs={'class':'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'})

# %%
links
# Out:
# [<a class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal" href="/PlayStation%C2%AE5-console-slim-PlayStation-5/dp/B0CL61F39H/ref=sr_1_1_mod_primary_new?crid=3BV45YDFQQE2G&amp;dib=eyJ2IjoiMSJ9.IBzp2a7hJYOBBKGDpX2BCAjIjGrN4dtfzoAawTrYYQrW5ObxkSL6eH768BU3qApilPX9qH0NuEongEspv6q737g0q0zahSuARurg6MJJx6klNDwA5gFFbjbD-gBIZTYxbCTZdk9Q_4fe2QVWe5DDP6DiqgQhvncli6Pn9Cpt9zq9iKXunekfBnVRyXZ2ObZTAZzFaBah6huKajdfkPZs2Uy6Mz10xcMEOibbW7RXIHQ.Y16ojCiZQjTWhmpkyRLJNHFUpHIFs5gE0WzbNTN81NA&amp;dib_tag=se&amp;keywords=playstation+5&amp;qid=1719758349&amp;sbo=RZvfv%2F%2FHxDF%2BO5021pAnSA%3D%3D&amp;sprefix=playstation+4%2Caps%2C269&amp;sr=8-1"><span class="a-size-medium a-color-base a-text-normal">PlayStation®5 console (slim)</span> </a>,
# ...

# %%
link=links[0].get('href')

# %%
link
# Out:
# '/PlayStation%C2%AE5-console-slim-PlayStation-5/dp/B0CL61F39H/ref=sr_1_1_mod_primary_new?crid=3BV45YDFQQE2G&dib=eyJ2IjoiMSJ9.IBzp2a7hJYOBBKGDpX2BCAjIjGrN4dtfzoAawTrYYQrW5ObxkSL6eH768BU3qApilPX9qH0NuEongEspv6q737g0q0zahSuARurg6MJJx6klNDwA5gFFbjbD-gBIZTYxbCTZdk9Q_4fe2QVWe5DDP6DiqgQhvncli6Pn9Cpt9zq9iKXunekfBnVRyXZ2ObZTAZzFaBah6huKajdfkPZs2Uy6Mz10xcMEOibbW7RXIHQ.Y16ojCiZQjTWhmpkyRLJNHFUpHIFs5gE0WzbNTN81NA&dib_tag=se&keywords=playstation+5&qid=1719758349&sbo=RZvfv%2F%2FHxDF%2BO5021pAnSA%3D%3D&sprefix=playstation+4%2Caps%2C269&sr=8-1'

# %%
product_list="https://amazon.com"+link

# %%
product_list
# Out:
# 'https://amazon.com/PlayStation%C2%AE5-console-slim-PlayStation-5/dp/B0CL61F39H/ref=sr_1_1_mod_primary_new?crid=3BV45YDFQQE2G&dib=eyJ2IjoiMSJ9.IBzp2a7hJYOBBKGDpX2BCAjIjGrN4dtfzoAawTrYYQrW5ObxkSL6eH768BU3qApilPX9qH0NuEongEspv6q737g0q0zahSuARurg6MJJx6klNDwA5gFFbjbD-gBIZTYxbCTZdk9Q_4fe2QVWe5DDP6DiqgQhvncli6Pn9Cpt9zq9iKXunekfBnVRyXZ2ObZTAZzFaBah6huKajdfkPZs2Uy6Mz10xcMEOibbW7RXIHQ.Y16ojCiZQjTWhmpkyRLJNHFUpHIFs5gE0WzbNTN81NA&dib_tag=se&keywords=playstation+5&qid=1719758349&sbo=RZvfv%2F%2FHxDF%2BO5021pAnSA%3D%3D&sprefix=playstation+4%2Caps%2C269&sr=8-1'

# %%
new_webpage=requests.get(product_list,headers=HEADERS)

# %%
new_webpage
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(webpage.content, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-us"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
# <script type="text/javascript">var ue_t0=ue_t0||+new Date();</script>
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-na.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# <script type="text/javascript">
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %%
new_soup.find("span", attrs={"id":'productTitle'}).text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 new_soup.find("span", attrs={"id":'productTitle'}).text
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
try:
    title = soup.find("span", attrs={"id": "productTitle"}).text.strip()
    print(f"Product Title: {title}")
except AttributeError:
    print("Product title not found or unable to retrieve text")
# Out:
# Product title not found or unable to retrieve text

# %%
try:
    product_title = soup.find("span", attrs={"id": "productTitle"}).text.strip()
    print("Product Title:", product_title)
except AttributeError as e:
    print("Product title not found or unable to retrieve text")
# Out:
# Product title not found or unable to retrieve text

# %%
soup.find("span", attrs={"id":'productTitle'}).text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 soup.find("span", attrs={"id":'productTitle'}).text
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
soup.find("span", attrs={"class":'a-price a-text-price a-size-medium'}).find("span", attrs={"class": "a-offscreen"}).text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 soup.find("span", attrs={"class":'a-price a-text-price a-size-medium'}).find("span", attrs={"class": "a-offscreen"}).text
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
soup.find("span", attrs={"class":'a-icon-alt'}).text
# Out:
# '4.7 out of 5 stars'

# %%
soup.find("span", attrs={"class":'a-price a-text-price a-size-medium'})

# %%
soup.find("span", attrs={"id":'productTitle'})

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
def get_title(soup):

    try:
        # Outer Tag Object
        title = soup.find("span", attrs={"id":'productTitle'})
        
        # Inner NavigatableString Object
        title_value = title.text

        # Title as a string value
        title_string = title_value.strip()

    except AttributeError:
        title_string = ""

    return title_string

# %%
def get_price(soup):

    try:
        price = soup.find("span", attrs={'id':'priceblock_ourprice'}).string.strip()

    except AttributeError:

        try:
            # If there is some deal price
            price = soup.find("span", attrs={'id':'priceblock_dealprice'}).string.strip()

        except:
            price = ""

    return price

# %%
def get_rating(soup):

    try:
        rating = soup.find("i", attrs={'class':'a-icon a-icon-star a-star-4-5'}).string.strip()
    
    except AttributeError:
        try:
            rating = soup.find("span", attrs={'class':'a-icon-alt'}).string.strip()
        except:
            rating = ""	

    return rating

# %%
def get_review_count(soup):
    try:
        review_count = soup.find("span", attrs={'id':'acrCustomerReviewText'}).string.strip()

    except AttributeError:
        review_count = ""	

    return review_count

# %%
def get_availability(soup):
    try:
        available = soup.find("div", attrs={'id':'availability'})
        available = available.find("span").string.strip()

    except AttributeError:
        available = "Not Available"	

    return available

# %%
if __name__ == '__main__':

    
    HEADERS = ({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36', 'Accept-Language': 'en-US, en;q=0.5'})

    URL = "https://www.amazon.com/s?k=playstation+4&ref=nb_sb_noss_2"

    webpage = requests.get(URL, headers=HEADERS)

    soup = BeautifulSoup(webpage.content, "html.parser")

    links = soup.find_all("a", attrs={'class':'a-link-normal s-no-outline'})


    links_list = []

    for link in links:
            links_list.append(link.get('href'))

    d = {"title":[], "price":[], "rating":[], "reviews":[],"availability":[]}
    for link in links_list:
        new_webpage = requests.get("https://www.amazon.com" + link, headers=HEADERS)

        new_soup = BeautifulSoup(new_webpage.content, "html.parser")

        # Function calls to display all necessary product information
        d['title'].append(get_title(new_soup))
        d['price'].append(get_price(new_soup))
        d['rating'].append(get_rating(new_soup))
        d['reviews'].append(get_review_count(new_soup))
        d['availability'].append(get_availability(new_soup))

    
    amazon_df = pd.DataFrame.from_dict(d)
    amazon_df['title'].replace('', np.nan, inplace=True)
    amazon_df = amazon_df.dropna(subset=['title'])
    amazon_df.to_csv("amazon_data.csv", header=True, index=False)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connection.py:196, in HTTPConnection._new_conn(self)
#     195 try:
# --> 196     sock = connection.create_connection(
#     197         (self._dns_host, self.port),
#     198         self.timeout,
#     199         source_address=self.source_address,
#     200         socket_options=self.socket_options,
#     201     )
#     202 except socket.gaierror as e:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\util\connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61     af, socktype, proto, canonname, sa = res
#
# ...

# %%
amazon_df
# Out:
#                                                 title price  \
# 0   PlayStation®4 Console – Call of Duty® Modern W...
# 1   Wireless Controller Dual Vibration Game Joysti...
# 2   FASIGO PS4 Controller 2 Pack, Wireless PS4 Con...
# 3   DualShock 4 Wireless Controller for PlayStatio...
# 4   PS4 Controller Wireless, with USB C Cable/1000...
# 5   Wireless Controller for PS4 with 2 Thumb Grips...
# 6                              Mortal Kombat XL (PS4)
# 7   OIVO PS4 Stand Cooling Fan Station for Playsta...
# 8   PS4 Controller Charger Dock Station, OIVO 1.8H...
# 9                  Minecraft Starter Collection (PS4)
# 10  KDYGPDCT 2 Pack Wireless Controller for PS4,Du...
# 11             Sony Playstation PS4 1TB Black Console
# 12                     PlayStation 4 Slim 1TB Console
# 13  Sony PlayStation 4 Slim Limited Edition 1TB Ga...
# 14  PlayStation 4 500GB Console [Old Model][Discon...
# 15  Sony PlayStation 4 Pro 1TB Console - Black (PS...
#
# ...
